# %%
import numpy as np
import pandas as pd

import re
import html
import requests

from datetime import datetime, date
import plotly.express as px
import plotly.graph_objs as go



def returncolname(row, colnames):
    if sum(row[['Q1', 'Q2','Q3','Q4']]) != 1:
        return colnames[np.argmax(row[['Q1_Prob', 'Q2_Prob','Q3_Prob','Q4_Prob']].values)]

def probabilityF(row):
    if row['colmax'] == 'Q1_Prob':
        return row.Q1_Prob
    elif row['colmax'] == 'Q2_Prob':
        return row.Q2_Prob
    elif row['colmax'] == 'Q3_Prob':
        return row.Q3_Prob
    elif row['colmax'] == 'Q4_Prob':
        return row.Q4_Prob

def Q1(row):
    if (row['Q1'] == 1.0) or (row['colmax'] == 'Q1_Prob'):
        return 1.0
    else:
        return 0.0
    
def Q2(row):
    if (row['Q2'] == 1.0) or (row['colmax'] == 'Q2_Prob'):
        return 1.0
    else:
        return 0.0

def Q3(row):
    if (row['Q3'] == 1.0) or (row['colmax'] == 'Q3_Prob'):
        return 1.0
    else:
        return 0.0
    
def Q4(row):
    if (row['Q4'] == 1.0) or (row['colmax'] == 'Q4_Prob'):
        return 1.0
    else:
        return 0.0
    
def q(row):
    if row['Q1 Posts'] == 1.0:
        return 'Q1'
    if row['Q2 Posts'] == 1.0:
        return 'Q2'
    if row['Q3 Posts'] == 1.0:
        return 'Q3'
    if row['Q4 Posts'] == 1.0:
        return 'Q4'
    else:
        return 'unk'

def buildout():
    """[Provides a final set of features showing which salary range applies to each data.]

    Returns:
        [csv]: [a table containing our original original, predicted, and bracket columns]
    """
    ### changed from app/
    df = pd.read_csv('../app/data/ml.csv')
    df['DatePosted'] = df['DatePosted'].astype('datetime64')
    df = df.sort_values(by="DatePosted")


    #df.replace(np.nan, 0, inplace = True)
    
    df['colmax'] = df.apply(lambda x: returncolname(x, df[['Q1_Prob', 'Q2_Prob','Q3_Prob','Q4_Prob']].columns), axis=1)
    df['Probability'] = df.apply(lambda x: probabilityF(x), axis=1)
    df['Q1 Posts'] = df.apply( lambda row : Q1(row), axis = 1)
    df['Q2 Posts'] = df.apply( lambda row : Q2(row), axis = 1)
    df['Q3 Posts'] = df.apply( lambda row : Q3(row), axis = 1)
    df['Q4 Posts'] = df.apply( lambda row : Q4(row), axis = 1)
    df['Q'] = df.apply( lambda row : q(row), axis = 1)

    
    df.Probability = df.Probability.fillna(1.0)
    # Saving final results table
    df.to_csv('../app/data/graph_ready.csv', index=False)
    
    # Creating and saving only observed salary data
    dfSal = df[df.Salary.notnull()]
    dfSal = dfSal[['DatePosted', 'Salary', 'Q']]
    dfSal.to_csv('../app/data/dfSal.csv', index=False)
    return df

# %%
df = buildout()

# %%
df.head(1)
# Out:
#        Company                                   JobTitle           Location  \
# 10748  twitter  product data scientist - ads data science  San Francisco, CA
#
#       Requirements                                            Summary  \
# 10748         none  2  years of work experience in data driven ana...
#
#                                              Description  \
# 10748  job descriptionwho we are the team is responsi...
#
#                                                   JobUrl  Salary State  \
# 10748  https://www.indeed.com/rc/clk?jk=ca532d30df581...     NaN    CA
#
#                 City  ... Q3_Prob Q4_Pred Q4_Prob   colmax  Probability  \
# 10748  san francisco  ...     1.0     0.0     0.0  Q3_Prob          1.0
#
#        Q1 Posts  Q2 Posts  Q3 Posts  Q4 Posts   Q
# 10748       0.0       0.0       1.0       0.0  Q3
#
# [1 rows x 33 columns]

# %%
from sklearn import metrics

# %%
df.columns
# Out:
# Index(['Company', 'JobTitle', 'Location', 'Requirements', 'Summary',
#        'Description', 'JobUrl', 'Salary', 'State', 'City', 'DatePosted',
#        'Schedule', 'Role', 'Focus', 'Q1', 'Q2', 'Q3', 'Q4', 'Q1_Pred',
#        'Q1_Prob', 'Q2_Pred', 'Q2_Prob', 'Q3_Pred', 'Q3_Prob', 'Q4_Pred',
#        'Q4_Prob', 'colmax', 'Probability', 'Q1 Posts', 'Q2 Posts', 'Q3 Posts',
#        'Q4 Posts', 'Q'],
#       dtype='object')

# %%
dfc = df[df.Salary.notnull()]

# %%
dfProbs = dfc[['Q1', 'Q2', 'Q3', 'Q4',
       'Q1_Pred', 'Q1_Prob', 'Q2_Pred', 'Q2_Prob', 'Q3_Pred', 'Q3_Prob',
       'Q4_Pred', 'Q4_Prob','Salary']]
dfProbs
# Out:
#         Q1   Q2   Q3   Q4  Q1_Pred  Q1_Prob  Q2_Pred  Q2_Prob  Q3_Pred  \
# 24074  0.0  0.0  0.0  1.0      NaN      NaN      NaN      NaN      NaN
# 24077  0.0  0.0  0.0  1.0      NaN      NaN      NaN      NaN      NaN
# 24083  0.0  0.0  0.0  1.0      NaN      NaN      NaN      NaN      NaN
# 24061  0.0  0.0  1.0  0.0      NaN      NaN      NaN      NaN      NaN
# 24035  0.0  0.0  1.0  0.0      NaN      NaN      NaN      NaN      NaN
# ...    ...  ...  ...  ...      ...      ...      ...      ...      ...
# 25344  1.0  0.0  0.0  0.0      NaN      NaN      NaN      NaN      NaN
# 25345  0.0  1.0  0.0  0.0      NaN      NaN      NaN      NaN      NaN
# 25346  1.0  0.0  0.0  0.0      NaN      NaN      NaN      NaN      NaN
# 25347  0.0  0.0  0.0  1.0      NaN      NaN      NaN      NaN      NaN
# 25340  1.0  0.0  0.0  0.0      NaN      NaN      NaN      NaN      NaN
#
#        Q3_Prob  Q4_Pred  Q4_Prob         Salary
# 24074      NaN      NaN      NaN  177500.000000
# 24077      NaN      NaN      NaN  135571.428571
# 24083      NaN      NaN      NaN  180000.000000
# 24061      NaN      NaN      NaN  114660.000000
# 24035      NaN      NaN      NaN  121325.000000
# ...        ...      ...      ...            ...
# 25344      NaN      NaN      NaN   31285.714286
# 25345      NaN      NaN      NaN   90803.000000
# 25346      NaN      NaN      NaN   62000.000000
# 25347      NaN      NaN      NaN  156428.571429
# 25340      NaN      NaN      NaN   58500.000000
#
# [2406 rows x 13 columns]

# %%
df2 = df[['Q1_Pred', 'Q2_Pred', 'Q3_Pred', 'Q4_Pred']]

# %%
df2
# Out:
#        Q1_Pred  Q2_Pred  Q3_Pred  Q4_Pred
# 10748      0.0      0.0      1.0      0.0
# 10381      0.0      0.0      0.0      0.0
# 10679      0.0      0.0      0.0      0.0
# 10684      0.0      1.0      1.0      0.0
# 10685      0.0      0.0      0.0      0.0
# ...        ...      ...      ...      ...
# 22590      0.0      0.0      0.0      1.0
# 22591      0.0      1.0      1.0      0.0
# 22592      1.0      1.0      0.0      0.0
# 22574      0.0      0.0      0.0      0.0
# 22754      0.0      0.0      1.0      0.0
#
# [25396 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Company', 'JobTitle', 'Location', 'Requirements', 'Summary',
#        'Description', 'JobUrl', 'Salary', 'State', 'City', 'DatePosted',
#        'Schedule', 'Role', 'Focus', 'Q1', 'Q2', 'Q3', 'Q4', 'Q1_Pred',
#        'Q1_Prob', 'Q2_Pred', 'Q2_Prob', 'Q3_Pred', 'Q3_Prob', 'Q4_Pred',
#        'Q4_Prob', 'colmax', 'Probability', 'Q1 Posts', 'Q2 Posts', 'Q3 Posts',
#        'Q4 Posts', 'Q'],
#       dtype='object')

# %%
df[['JobTitle', 'Company', 'Location', 'Summary', 'JobUrl', 'Requirements',
       'Description', 'State', 'DatePosted','Salary','Probability','Q'] ].reset_index()
# Out:
#        index                                     JobTitle             Company  \
# 0      10748    product data scientist - ads data science             twitter
# 1      10381  data scientist, operations decision science               delta
# 2      10679                               data scientist       commerce bank
# 3      10684            data scientist - customer service          dte energy
# 4      10685                     associate data scientist  catalina marketing
# ...      ...                                          ...                 ...
# 25391  22590          sr mgr marketing analytics - remote         thryv, inc.
# 25392  22591                            corporate counsel            coursera
# 25393  22592                              biostatistician               avera
# 25394  22574           data scientist - product analytics         match group
# 25395  22754                       finance manager - xbox           microsoft
#
#                                 Location  \
# 0                      San Francisco, CA
# 1                            Atlanta, GA
# 2                        Kansas City, MO
# 3                            Detroit, MI
# 4                            Chicago, IL
# ...                                  ...
# 25391               United States•Remote
# 25392                             Remote
# 25393              Sioux Falls, SD 57105
# 25394                         Dallas, TX
# 25395  Redmond, WA 98052 (Overlake area)
#
#                                                  Summary  \
# 0      2  years of work experience in data driven ana...
# 1      an appropriate candidate will have a proven ex...
# 2      1 2 years statistical analysis  machine learni...
# 3      experience in quantitative analytics  e g  dat...
# 4      research and test new measurement and targetin...
# ...                                                  ...
# 25391  must be 18 years of age or older  you will be ...
# 25392  legal and compliance is responsible for managi...
# 25393  masters degree or phd in biostatistics  statis...
# 25394  you have at least 2 years of professional expe...
# 25395  bachelor's degree in business administration  ...
#
#                                                   JobUrl Requirements  \
# 0      https://www.indeed.com/rc/clk?jk=ca532d30df581...         none
# 1      https://www.indeed.com/rc/clk?jk=1cb59dd5ec8ba...         none
# 2      https://www.indeed.com/rc/clk?jk=68c23b12100e4...         none
# 3      https://www.indeed.com/rc/clk?jk=caf39a8e478b2...         none
# 4      https://www.indeed.com/rc/clk?jk=cc3a61acd7a7c...         none
# ...                                                  ...          ...
# 25391  https://www.indeed.com/rc/clk?jk=50c2fe5a216f9...         none
# 25392  https://www.indeed.com/rc/clk?jk=e3042ccfbf8bf...         none
# 25393  https://www.indeed.com/rc/clk?jk=7078273ad6368...         none
# 25394  https://www.indeed.com/rc/clk?jk=006e78a03c017...         none
# 25395  https://www.indeed.com/rc/clk?jk=895e7d7ba9c06...         none
#
#                                              Description   State DatePosted  \
# 0      job descriptionwho we are the team is responsi...      CA 2021-04-14
# 1      the operations analysis   performance  oap  te...      GA 2021-04-14
# 2      about working at commercewouldn’t it be great ...      MO 2021-04-14
# 3      the future is bright at dte energy  we are one...      MI 2021-04-14
# 4      the digital analytics team at catalina is resp...      IL 2021-04-14
# ...                                                  ...     ...        ...
# 25391  as sr manager marketing analytics you will lea...  Remote 2021-08-17
# 25392  coursera was launched in 2012 by two stanford ...  Remote 2021-08-17
# 25393  job summary  the overall function of this role...      SD 2021-08-17
# 25394  match boasts more dates  more relationships an...      TX 2021-08-17
# 25395  finance manager  xbox central financethe gamin...      WA 2021-08-17
#
#        Salary  Probability   Q
# 0         NaN         1.00  Q3
# 1         NaN         0.32  Q4
# 2         NaN         0.32  Q4
# 3         NaN         0.99  Q3
# 4         NaN         0.00  Q1
# ...       ...          ...  ..
# 25391     NaN         0.98  Q4
# 25392     NaN         0.99  Q2
# 25393     NaN         1.00  Q1
# 25394     NaN         0.32  Q4
# 25395     NaN         0.98  Q3
#
# [25396 rows x 13 columns]

# %%
a = df[df.Salary.isnull()]

# %%
b= df[df.Salary.notnull()]

# %%
df[df.Probability.isnull()]
# Out:
# Empty DataFrame
# Columns: [Company, JobTitle, Location, Requirements, Summary, Description, JobUrl, Salary, State, City, DatePosted, Schedule, Role, Focus, Q1, Q2, Q3, Q4, Q1_Pred, Q1_Prob, Q2_Pred, Q2_Prob, Q3_Pred, Q3_Prob, Q4_Pred, Q4_Prob, colmax, Probability, Q1 Posts, Q2 Posts, Q3 Posts, Q4 Posts, Q]
# Index: []
#
# [0 rows x 33 columns]

# %%
z = pd.concat([a,b])

# %%
za = z[['Salary', 'Company', 'Location', 'Summary', 'JobUrl', 'Requirements',
       'Description', 'State', 'DatePosted','Probability','Q']]
zb = z[['Salary', 'Q1', 'Q2', 'Q3', 'Q4', 'Q1_Pred',
       'Q1_Prob', 'Q2_Pred', 'Q2_Prob', 'Q3_Pred', 'Q3_Prob', 'Q4_Pred',
       'Q4_Prob', 'colmax', 'Q1 Posts', 'Q2 Posts', 'Q3 Posts',
       'Q4 Posts', 'Probability', 'Q']]

# %%
za
# Out:
#               Salary                                            Company  \
# 10748            NaN                                            twitter
# 10381            NaN                                              delta
# 10679            NaN                                      commerce bank
# 10684            NaN                                         dte energy
# 10685            NaN                                 catalina marketing
# ...              ...                                                ...
# 25344   31285.714286                                             rhythm
# 25345   90803.000000                        equal employ practices comm
# 25346   62000.000000  veterans research and education foundation of ...
# 25347  156428.571429                                  yellow jacket inc
# 25340   58500.000000                                  blue moon digital
#
#                                     Location  \
# 10748                      San Francisco, CA
# 10381                            Atlanta, GA
# 10679                        Kansas City, MO
# 10684                            Detroit, MI
# 10685                            Chicago, IL
# ...                                      ...
# 25344                               Katy, TX
# 25345                          Manhattan, NY
# 25346                    St. Louis, MO 63103
# 25347                             Boston, MA
# 25340  Denver, CO 80202 (Union Station area)
#
#                                                  Summary  \
# 10748  2  years of work experience in data driven ana...
# 10381  an appropriate candidate will have a proven ex...
# 10679  1 2 years statistical analysis  machine learni...
# 10684  experience in quantitative analytics  e g  dat...
# 10685  research and test new measurement and targetin...
# ...                                                  ...
# 25344  high school diploma or ged certificate  high s...
# 25345  for assignment level i  only physical  biologi...
# 25346  experience managing or utilizing data warehous...
# 25347  6 8 yrs  of experience working in advanced ana...
# 25340  bachelor's degree  or equivalent work experien...
#
#                                                   JobUrl  \
# 10748  https://www.indeed.com/rc/clk?jk=ca532d30df581...
# 10381  https://www.indeed.com/rc/clk?jk=1cb59dd5ec8ba...
# 10679  https://www.indeed.com/rc/clk?jk=68c23b12100e4...
# 10684  https://www.indeed.com/rc/clk?jk=caf39a8e478b2...
# 10685  https://www.indeed.com/rc/clk?jk=cc3a61acd7a7c...
# ...                                                  ...
# 25344  https://www.indeed.com/company/Rhythm/jobs/Ent...
# 25345  https://www.indeed.com/rc/clk?jk=983ec8e54f1ca...
# 25346  https://www.indeed.com/company/Veterans-Resear...
# 25347  https://www.indeed.com/company/Yellow-Jacket-I...
# 25340  https://www.indeed.com/rc/clk?jk=8b6c9dbdbdb85...
#
#                                             Requirements  \
# 10748                                               none
# 10381                                               none
# 10679                                               none
# 10684                                               none
# 10685                                               none
# ...                                                  ...
# 25344  high school or equivalent (preferred)sales exp...
# 25345                                               none
# 25346  master's (required)us work authorization (requ...
# 25347  sql: 5 years (preferred)advanced analytics: 5 ...
# 25340                                               none
#
#                                              Description State DatePosted  \
# 10748  job descriptionwho we are the team is responsi...    CA 2021-04-14
# 10381  the operations analysis   performance  oap  te...    GA 2021-04-14
# 10679  about working at commercewouldn’t it be great ...    MO 2021-04-14
# 10684  the future is bright at dte energy  we are one...    MI 2021-04-14
# 10685  the digital analytics team at catalina is resp...    IL 2021-04-14
# ...                                                  ...   ...        ...
# 25344  rhythm is a renewable energy and technology co...    TX 2021-08-17
# 25345  the equal employment practices commission  emp...    NY 2021-08-17
# 25346  biostatistician programmer data scientist the ...    MO 2021-08-17
# 25347  key responsibilities· partner with internal st...    MA 2021-08-17
# 25340  about uswe are data nerds with marketing souls...    CO 2021-08-17
#
#        Probability   Q
# 10748         1.00  Q3
# 10381         0.32  Q4
# 10679         0.32  Q4
# 10684         0.99  Q3
# 10685         0.00  Q1
# ...            ...  ..
# 25344         1.00  Q1
# 25345         1.00  Q2
# 25346         1.00  Q1
# 25347         1.00  Q4
# 25340         1.00  Q1
#
# [25396 rows x 11 columns]

# %%
zb
# Out:
#               Salary   Q1   Q2   Q3   Q4  Q1_Pred  Q1_Prob  Q2_Pred  Q2_Prob  \
# 10748            NaN  NaN  NaN  NaN  NaN      0.0      0.0      0.0     0.00
# 10381            NaN  NaN  NaN  NaN  NaN      0.0      0.0      0.0     0.00
# 10679            NaN  NaN  NaN  NaN  NaN      0.0      0.0      0.0     0.00
# 10684            NaN  NaN  NaN  NaN  NaN      0.0      0.0      1.0     0.92
# 10685            NaN  NaN  NaN  NaN  NaN      0.0      0.0      0.0     0.00
# ...              ...  ...  ...  ...  ...      ...      ...      ...      ...
# 25344   31285.714286  1.0  0.0  0.0  0.0      NaN      NaN      NaN      NaN
# 25345   90803.000000  0.0  1.0  0.0  0.0      NaN      NaN      NaN      NaN
# 25346   62000.000000  1.0  0.0  0.0  0.0      NaN      NaN      NaN      NaN
# 25347  156428.571429  0.0  0.0  0.0  1.0      NaN      NaN      NaN      NaN
# 25340   58500.000000  1.0  0.0  0.0  0.0      NaN      NaN      NaN      NaN
#
#        Q3_Pred  Q3_Prob  Q4_Pred  Q4_Prob   colmax  Q1 Posts  Q2 Posts  \
# 10748      1.0     1.00      0.0     0.00  Q3_Prob       0.0       0.0
# 10381      0.0     0.00      0.0     0.32  Q4_Prob       0.0       0.0
# 10679      0.0     0.04      0.0     0.32  Q4_Prob       0.0       0.0
# 10684      1.0     0.99      0.0     0.00  Q3_Prob       0.0       0.0
# 10685      0.0     0.00      0.0     0.00  Q1_Prob       1.0       0.0
# ...        ...      ...      ...      ...      ...       ...       ...
# 25344      NaN      NaN      NaN      NaN     None       1.0       0.0
# 25345      NaN      NaN      NaN      NaN     None       0.0       1.0
# 25346      NaN      NaN      NaN      NaN     None       1.0       0.0
# 25347      NaN      NaN      NaN      NaN     None       0.0       0.0
# 25340      NaN      NaN      NaN      NaN     None       1.0       0.0
#
#        Q3 Posts  Q4 Posts  Probability   Q
# 10748       1.0       0.0         1.00  Q3
# 10381       0.0       1.0         0.32  Q4
# 10679       0.0       1.0         0.32  Q4
# 10684       1.0       0.0         0.99  Q3
# 10685       0.0       0.0         0.00  Q1
# ...         ...       ...          ...  ..
# 25344       0.0       0.0         1.00  Q1
# 25345       0.0       0.0         1.00  Q2
# 25346       0.0       0.0         1.00  Q1
# 25347       0.0       1.0         1.00  Q4
# 25340       0.0       0.0         1.00  Q1
#
# [25396 rows x 20 columns]

# %%
c = df2[df2.Salary.isnull()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-b196689adfde> in <module>
# ----> 1 c = df2[df2.Salary.isnull()]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5460             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5461                 return self[name]
# -> 5462             return object.__getattribute__(self, name)
#    5463
#    5464     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Salary'

# %%
d = df2[df2.Salary.notnull()]

# %%
zz = pd.concat([c,d])
zz

# %%
a = sum(df['Q1 Posts'] ==1)
a

# %%
b = sum(df['Q2 Posts'] ==1)
b

# %%
c = sum(df['Q3 Posts'] ==1)
c

# %%
d = sum(df['Q4 Posts'] ==1)
d

# %%
sum([a,b,c,d])

# %%
dd = pd.read_csv('../app/data/ml.csv')

# %%
dd.columns

# %%
dd
